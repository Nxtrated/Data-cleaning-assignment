# %%
import numpy as np
import pandas as pd

# %%
c = pd.read_csv('/content/messy_data.csv')
c
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %%
c.shape
# Out:
# (10100, 10)

# %%
c.head ()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
c.duplicated().sum()
# Out:
# 100

# %%
c.drop_duplicates(keep = 'first', inplace = True)
c
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %%
c.isnull().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName       994
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1439
# CusterAge         0
# dtype: int64

# %%
c['PaymentType'].replace({'paypal': 'Paypal', 'Debit': 'Debit Card', 'debit card': 'Debit Card', 'Credit': 'Credit Card'}, inplace=True)
c
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %%
c.rename(columns = {'TrnsnID': 'TransactionID', 'Data':'Date', 'CusmrID':'CustomerID', 'ProdtID':'ProductID','ProdtName' : 'ProductName', 'Qutity':'Quantity', 'Prize' : 'Price', 'TtlSales': 'TotalSales', 'CusterAge': 'CustomerAge'}, inplace = True)
c
# Out:
#        TransactionID        Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402  03/17/2026         991       1045       Boo E         9
# 1               5835  26-01-2035         741       1040      Book J        18
# 2               2123  05/26/2035         933       1062       Bok N         5
# 3               8789  28-02-2036         641       1060      Book I         6
# 4                305  19-04-2023         123       1058      Book B        15
# ...              ...         ...         ...        ...         ...       ...
# 10095           5735  04/03/2027          52       1066      Book G         1
# 10096           5192  08/16/2025         334       1093       Bok N        -2
# 10097           5391  06/18/2026         657       1047     Bookk H         5
# 10098            861  04/08/2034         579       1014       Bok N        19
# 10099           7271  26-04-2029         153       1052      Book T        10
#
# ...

# %%
c['Date'] = pd.to_datetime(c['Date'], format='mixed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-4fabd3f4f62d> in <cell line: 1>()
# ----> 1 c['Date'] = pd.to_datetime(c['Date'], format='mixed')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.map(cache_array)
#    1067         else:
# -> 1068             values = convert_listlike(arg._values, format)
#    1069             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     428
# ...
